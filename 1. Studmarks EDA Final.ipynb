# %%
import mysql.connector
import pandas as pd
con = mysql.connector.connect(
    host="localhost",
    port=3306,
    user="root",
    password="Deepak169$",
    database="number")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
stu = pd.read_sql_query("select * from studmarks",con)
stu
stu.head(10)
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
stu.tail()
# Out:
#      Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 5    Annu      F  05-04-1988     45       87         52       89       55
# 6   pooja      F  04-05-1987     55       64         61       58       75
# 7  Ritesh      M  25-05-1989     54       76         87       56       25
# 8   Farha      F  12-08-1990     55       63         89       75       78
# 9  Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 5         89       87      52
# 6         58       64      61
# 7         56       76      87
# 8         75       63      89
# 9         83       46      77

# %%
stu.dtypes
# Out:
# Name         object
# Gender       object
# DOB          object
# Maths         int64
# Physics       int64
# Chemistry     int64
# English       int64
# Biology       int64
# Economics     int64
# History       int64
# Civics        int64
# dtype: object

# %%
stu.describe()   # we can seee that on an avg , scored more in chemistry
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
stu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       10 non-null     object
#  1   Gender     10 non-null     object
#  2   DOB        10 non-null     object
#  3   Maths      10 non-null     int64
#  4   Physics    10 non-null     int64
#  5   Chemistry  10 non-null     int64
#  6   English    10 non-null     int64
#  7   Biology    10 non-null     int64
#  8   Economics  10 non-null     int64
#  9   History    10 non-null     int64
#  10  Civics     10 non-null     int64
# dtypes: int64(8), object(3)
# memory usage: 1008.0+ bytes

# %%
stu.isnull().sum()
# Out:
# Name         0
# Gender       0
# DOB          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %%
sns.countplot(x="Maths" ,hue ="Gender",data=stu)

# %%
sns.countplot(x="Physics" ,hue ="Gender",data=stu)

# %%
sns.countplot(x="Chemistry" ,hue ="Gender",data=stu)

# %%
sns.countplot(x="Biology" ,hue ="Gender",data=stu)

# %%
sns.countplot(x="History" ,hue ="Gender",data=stu )

# %%
sns.countplot(x="Civics" ,hue ="Gender",data=stu)

# %%
sns.countplot(x='Economics' ,hue ="Gender",data=stu)

# %%
sns.countplot(x="English" ,hue ="Gender",data=stu)

# %%
stu.plot(kind="box",subplots = True,layout=(10,5),figsize=(18,18))
# Out:
# Maths           AxesSubplot(0.125,0.816017;0.133621x0.0639831)
# Physics      AxesSubplot(0.285345,0.816017;0.133621x0.0639831)
# Chemistry     AxesSubplot(0.44569,0.816017;0.133621x0.0639831)
# English      AxesSubplot(0.606034,0.816017;0.133621x0.0639831)
# Biology      AxesSubplot(0.766379,0.816017;0.133621x0.0639831)
# Economics       AxesSubplot(0.125,0.739237;0.133621x0.0639831)
# History      AxesSubplot(0.285345,0.739237;0.133621x0.0639831)
# Civics        AxesSubplot(0.44569,0.739237;0.133621x0.0639831)
# dtype: object

# %%
sns.pairplot(stu)

# %%
sns.distplot(stu["Maths"]) # max students scored betwee 55-70

# %%
sns.distplot(stu["Physics"])

# %%
sns.distplot(stu['Chemistry'])# max students scored betwee 70-85

# %%
sns.distplot(stu["Biology"])# max students scored betwee 75-95

# %%
sns.distplot(stu["English"])# max students scored between 75-90

# %%
sns.distplot(stu["Civics"]) # max students scored betwee 45-85

# %%
sns.distplot(stu["Economics"])

# %%
sns.distplot(stu["History"])# max students scored betwee 75-90

# %%
stu.hist(figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021693F781C8>,
# ...
#       dtype=object)

# %%
sns.violinplot(x="Maths",data=stu)

# %%
sns.violinplot(x="Physics",data=stu)

# %%
sns.violinplot(x="Chemistry",data=stu)

# %%
sns.violinplot(x='Biology',data=stu)

# %%
sns.violinplot(x="English",data=stu)

# %%
sns.violinplot(x="History",data=stu)

# %%
sns.violinplot(x="Civics",data=stu)

# %%
sns.violinplot(x="Economics",data=stu)

# %% [markdown]
#  majority of students performed well in physics as well as in Chemistry
